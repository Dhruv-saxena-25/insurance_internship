# %%
import pandas as pd

# %%
df = pd.read_csv("../data\\insurance.csv")
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
data= df.to_dict(orient= 'records')
data
# Out:
# [{'age': 19,
#   'sex': 'female',
#   'bmi': 27.9,
#   'children': 0,
#   'smoker': 'yes',
#   'region': 'southwest',
#   'expenses': 16884.92},
#  {'age': 18,
#   'sex': 'male',
#   'bmi': 33.8,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 1725.55},
#  {'age': 28,
#   'sex': 'male',
#   'bmi': 33.0,
#   'children': 3,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 4449.46},
#  {'age': 33,
#   'sex': 'male',
#   'bmi': 22.7,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 21984.47},
#  {'age': 32,
#   'sex': 'male',
#   'bmi': 28.9,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'northwest',
#   'expenses': 3866.86},
#  {'age': 31,
#   'sex': 'female',
#   'bmi': 25.7,
#   'children': 0,
#   'smoker': 'no',
#   'region': 'southeast',
#   'expenses': 3756.62},
#  {'age': 46,
#   'sex': 'female',
#   'bmi': 33.4,
#   'children': 1,
#   'smoker': 'no',
#   'region': 'southeast',
# ...

# %%
DB_NAME = 'internship'
COLLECTION_NAME = 'insurance_data'
COLLECTION_URL = "mongodb+srv://dhruv:DHRUV@cluster0.clcbsrx.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
import pymongo

# %%
import certifi
client = pymongo.MongoClient(COLLECTION_URL, tlsCAFile= certifi.where())
# To create DataBase
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]
# To insert data into the Collection
record= collection.insert_many(data)

# %%
records= collection.find()

# %%
for i, j in enumerate(records):
    print(f'{i}: {j}')
# Out:
# 0: {'_id': ObjectId('667c28e6000238c485569504'), 'age': 19, 'sex': 'female', 'bmi': 27.9, 'children': 0, 'smoker': 'yes', 'region': 'southwest', 'expenses': 16884.92}
# 1: {'_id': ObjectId('667c28e6000238c485569505'), 'age': 18, 'sex': 'male', 'bmi': 33.8, 'children': 1, 'smoker': 'no', 'region': 'southeast', 'expenses': 1725.55}
# 2: {'_id': ObjectId('667c28e6000238c485569506'), 'age': 28, 'sex': 'male', 'bmi': 33.0, 'children': 3, 'smoker': 'no', 'region': 'southeast', 'expenses': 4449.46}
# 3: {'_id': ObjectId('667c28e6000238c485569507'), 'age': 33, 'sex': 'male', 'bmi': 22.7, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 21984.47}
# 4: {'_id': ObjectId('667c28e6000238c485569508'), 'age': 32, 'sex': 'male', 'bmi': 28.9, 'children': 0, 'smoker': 'no', 'region': 'northwest', 'expenses': 3866.86}
# 5: {'_id': ObjectId('667c28e6000238c485569509'), 'age': 31, 'sex': 'female', 'bmi': 25.7, 'children': 0, 'smoker': 'no', 'region': 'southeast', 'expenses': 3756.62}
# ...

# %%
df = pd.DataFrame(list(collection.find()))
df.head()
# Out:
#                         _id  age     sex   bmi  children smoker     region  \
# 0  667c28e6000238c485569504   19  female  27.9         0    yes  southwest
# 1  667c28e6000238c485569505   18    male  33.8         1     no  southeast
# 2  667c28e6000238c485569506   28    male  33.0         3     no  southeast
# 3  667c28e6000238c485569507   33    male  22.7         0     no  northwest
# 4  667c28e6000238c485569508   32    male  28.9         0     no  northwest
#
#    expenses
# 0  16884.92
# 1   1725.55
# 2   4449.46
# 3  21984.47
# 4   3866.86

# %%
if "_id" in df.columns.to_list():
    df = df.drop(columns=['_id'], axis=1)

# %%
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86
